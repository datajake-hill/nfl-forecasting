# %%
import numpy as np
import pandas as pd
from datetime import datetime
from matplotlib import pyplot as plt

pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %%
pff = pd.read_csv('pff.csv', index_col=0)

# %%
pff.head(2)
# Out:
#                 Team        Opposing Team  Season Week   Date    Time H/A W/L  \
# 0  Arizona Cardinals  San Francisco 49Ers    2006    1  09/10  4:15pm   H   W
# 1  Arizona Cardinals     Seattle Seahawks    2006    2  09/17  4:05pm   A   L
#
#    PF  PA   OVR   OFF  PASS  PBLK  RECV   RUN  RBLK   DEF  RDEF  TACK  PRSH  \
# 0  34  27  72.5  72.6  75.5  72.4  76.5  47.4  65.6  67.7  69.8  37.5  56.2
# 1  10  21  48.0  50.1  27.9  57.1  65.3  59.7  62.1  49.8  38.3  44.7  60.5
#
#     COV SPEC  OVR_opp  OFF_opp  PASS_opp  PBLK_opp  RECV_opp  RUN_opp  \
# 0  70.7    -     63.8     64.7      54.5      83.6      62.0     67.4
# 1  62.3    -     80.2     70.2      56.5      68.6      57.6     63.5
#
#    RBLK_opp  DEF_opp  RDEF_opp  TACK_opp  PRSH_opp  COV_opp SPEC_opp
# 0      63.6     61.4      63.2      32.0      69.0     53.8        -
# 1      85.4     85.5      72.8      61.2      73.4     84.0        -

# %%
stats = pff.iloc[:,8:]

# %%
import seaborn as sns
f, ax = plt.subplots(figsize=(8, 8))
corr = stats.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %%
# https://stackoverflow.com/questions/29432629/plot-correlation-matrix-using-pandas
corr = stats.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# use this to change the font size
# .set_properties(**{'font-size': '11pt'})
# 'RdBu_r' & 'BrBG' are other good diverging colormaps
# Out:
# <style  type="text/css" >
#     #T_d854d4ac_9a51_11ea_a3f7_9cb6d08ceb86row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d854d4ac_9a51_11ea_a3f7_9cb6d08ceb86row0_col1 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_d854d4ac_9a51_11ea_a3f7_9cb6d08ceb86row0_col2 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_d854d4ac_9a51_11ea_a3f7_9cb6d08ceb86row0_col3 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_d854d4ac_9a51_11ea_a3f7_9cb6d08ceb86row0_col4 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_d854d4ac_9a51_11ea_a3f7_9cb6d08ceb86row0_col5 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_d854d4ac_9a51_11ea_a3f7_9cb6d08ceb86row0_col6 {
#             background-color:  #f4987a;
#             color:  #000000;
# ...

# %%
list(plt.rcParams['axes.prop_cycle'])
# Out:
# [{'color': '#E24A33'},
#  {'color': '#348ABD'},
#  {'color': '#988ED5'},
#  {'color': '#777777'},
#  {'color': '#FBC15E'},
#  {'color': '#8EBA42'},
#  {'color': '#FFB5B8'}]

# %% [markdown]
# # PF

# %%
# https://matplotlib.org/3.1.1/gallery/style_sheets/ggplot.html
plt.style.use('ggplot')
fig = plt.figure(figsize=(8, 6))
stats.corr()['PF'].plot(kind='bar') # , color=list(plt.rcParams['axes.prop_cycle'])[6]['color']

# %% [markdown]
# # PA

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['PA'].plot(kind='bar')

# %% [markdown]
# # OVR

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['OVR'].plot(kind='bar')

# %% [markdown]
# # OFF

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['OFF'].plot(kind='bar')

# %% [markdown]
# # PASS

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['PASS'].plot(kind='bar')

# %% [markdown]
# # PBLK

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['PBLK'].plot(kind='bar')

# %% [markdown]
# # RECV

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['RECV'].plot(kind='bar')

# %% [markdown]
# # RUN

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['RUN'].plot(kind='bar')

# %% [markdown]
# # RBLK

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['RBLK'].plot(kind='bar')

# %% [markdown]
# # DEF

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['DEF'].plot(kind='bar')

# %% [markdown]
# # RDEF

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['RDEF'].plot(kind='bar')

# %% [markdown]
# # TACK

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['TACK'].plot(kind='bar')

# %% [markdown]
# # PRSH

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['PRSH'].plot(kind='bar')

# %% [markdown]
# # COV

# %%
fig = plt.figure(figsize=(8, 6))
stats.corr()['COV'].plot(kind='bar')
