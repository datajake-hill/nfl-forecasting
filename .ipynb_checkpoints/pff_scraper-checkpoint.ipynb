# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import pandas as pd
import re
import os
import time
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# from geopy.distance import geodesic
import sklearn
import random

# %%
# list of nfl teams
teams = ['arizona-cardinals', 'atlanta-falcons','baltimore-ravens','buffalo-bills','carolina-panthers','chicago-bears','cincinnati-bengals','cleveland-browns','dallas-cowboys','denver-broncos','detroit-lions','green-bay-packers','houston-texans','indianapolis-colts','jacksonville-jaguars','kansas-city-chiefs','los-angeles-chargers','los-angeles-rams','miami-dolphins','minnesota-vikings','new-england-patriots','new-orleans-saints','new-york-giants','new-york-jets','oakland-raiders','philadelphia-eagles','pittsburgh-steelers','san-francisco-49ers','seattle-seahawks','tampa-bay-buccaneers','tennessee-titans','washington-redskins']
# seasons to scrape
years = ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']
# years = ['2019']

# INITIALIZE DRIVER
driver = webdriver.Chrome(r'C:\Users\jakeh\Downloads\chromedriver_win32_v_80.0.3987.163\chromedriver.exe')
driver.get('https://www.profootballfocus.com/amember/login?amember_redirect_url=%2Fauth%2Ftokenize%3Freturn_url%3Dhttps%3A%2F%2Fpremium.profootballfocus.com%2Fauth%2Fcallback')
time.sleep(2+random.randint(1,4))
driver.find_element_by_id('login').send_keys("cvkrawcz")
time.sleep(2+random.randint(1,4))
driver.find_element_by_id('pass').send_keys("Degenerates5!")

# %%
import random
team = []
count = 0

for t in teams:
    for y in years: 
        driver.get("https://premium.pff.com/nfl/teams/" + str(t) + "/summary?season=" + str(y) + "&weekGroup=REGPO#")
        time.sleep(3+random.randint(5,7))

        items = driver.find_elements_by_class_name("kyber-table-body__row")
        for i in items:
            team.append(i.get_property('outerText'))
        team.append(y)
    team.append(t)

print(team)
    
driver.close()
# Out:
# now scraping... arizona-cardinals
# year... 2019
# now scraping... atlanta-falcons
# year... 2019
# now scraping... baltimore-ravens
# year... 2019
# now scraping... buffalo-bills
# year... 2019
# now scraping... carolina-panthers
# year... 2019
# now scraping... chicago-bears
# year... 2019
# now scraping... cincinnati-bengals
# year... 2019
# now scraping... cleveland-browns
# year... 2019
# now scraping... dallas-cowboys
# year... 2019
# now scraping... denver-broncos
# year... 2019
# now scraping... detroit-lions
# year... 2019
# now scraping... green-bay-packers
# year... 2019
# now scraping... houston-texans
# year... 2019
# now scraping... indianapolis-colts
# year... 2019
# now scraping... jacksonville-jaguars
# year... 2019
# now scraping... kansas-city-chiefs
# year... 2019
# now scraping... los-angeles-chargers
# year... 2019
# now scraping... los-angeles-rams
# year... 2019
# now scraping... miami-dolphins
# year... 2019
# now scraping... minnesota-vikings
# year... 2019
# now scraping... new-england-patriots
# year... 2019
# now scraping... new-orleans-saints
# year... 2019
# now scraping... new-york-giants
# year... 2019
# now scraping... new-york-jets
# year... 2019
# now scraping... oakland-raiders
# year... 2019
# now scraping... philadelphia-eagles
# year... 2019
# now scraping... pittsburgh-steelers
# year... 2019
# now scraping... san-francisco-49ers
# year... 2019
# now scraping... seattle-seahawks
# year... 2019
# now scraping... tampa-bay-buccaneers
# year... 2019
# now scraping... tennessee-titans
# year... 2019
# now scraping... washington-redskins
# year... 2019
