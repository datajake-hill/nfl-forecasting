# %%
import pandas as pd
import numpy as np

pff = pd.read_csv('pff_pi.csv', index_col = 0)
# pff['Date'].apply(lambda x : if )

# %%
pff['Date'].map(lambda x : x[:2] < '05').value_counts()
# Out:
# False    7008
# True      160
# Name: Date, dtype: int64

# %%
pff[pff['Date'].map(lambda x : x[:2] < '05')]
# Out:
#                      Team         Opposing Team  Season  Week        Date  \
# 1790      Atlanta Falcons  Tampa Bay Buccaneers    2009    17  01/03/2009
# 1791        Buffalo Bills    Indianapolis Colts    2009    17  01/03/2009
# 1792    Carolina Panthers    New Orleans Saints    2009    17  01/03/2009
# 1793        Chicago Bears         Detroit Lions    2009    17  01/03/2009
# 1794     Cleveland Browns  Jacksonville Jaguars    2009    17  01/03/2009
# ...                   ...                   ...     ...   ...         ...
# 5393  San Francisco 49Ers      Seattle Seahawks    2016    17  01/01/2016
# 5394     Seattle Seahawks   San Francisco 49Ers    2016    17  01/01/2016
# 5395  Washington Redskins       New York Giants    2016    17  01/01/2016
# 5396        Detroit Lions     Green Bay Packers    2016    17  01/01/2016
# 5397    Green Bay Packers         Detroit Lions    2016    17  01/01/2016
#
#         Time H/A W/L  PF  PA  ...  PBLK_opp  RECV_opp  RUN_opp  RBLK_opp  \
# ...

# %%
pff.head(50)
# Out:
#                     Team         Opposing Team  Season  Week        Date  \
# 0         Miami Dolphins   Pittsburgh Steelers    2006     1  09/07/2006
# 1    Pittsburgh Steelers        Miami Dolphins    2006     1  09/07/2006
# 2        Atlanta Falcons     Carolina Panthers    2006     1  09/10/2006
# 3       Baltimore Ravens  Tampa Bay Buccaneers    2006     1  09/10/2006
# 4          Buffalo Bills  New England Patriots    2006     1  09/10/2006
# 5      Carolina Panthers       Atlanta Falcons    2006     1  09/10/2006
# 6     Cincinnati Bengals    Kansas City Chiefs    2006     1  09/10/2006
# 7       Cleveland Browns    New Orleans Saints    2006     1  09/10/2006
# 8         Denver Broncos      Los Angeles Rams    2006     1  09/10/2006
# 9          Detroit Lions      Seattle Seahawks    2006     1  09/10/2006
# 10        Houston Texans   Philadelphia Eagles    2006     1  09/10/2006
# 11    Kansas City Chiefs    Cincinnati Bengals    2006     1  09/10/2006
# ...
